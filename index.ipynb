# %%
import pandas as pd
link1= "https://github.com/davasquezm/PC2/raw/refs/heads/main/HDI.xlsx%20-%20Table%201.csv"
gubo= pd.read_csv(link1)
gubo
# Out:
#          Back Table 1. Human Development Index and its components   \
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 4    HDI rank                                            Country
# ..        ...                                                ...
# 271       NaN                          Column 2: UNDESA (2022a).
# 272       NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 273       NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 274       NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 275       NaN  Column 6: Calculated based on data in columns ...
#
#                          Unnamed: 2  Unnamed: 3                Unnamed: 4  \
# 0                               NaN         NaN                       NaN
# ...

# %%
gubo.columns.to_list()
# Out:
# ['Back',
#  'Table 1. Human Development Index and its components ',
#  'Unnamed: 2',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  'Unnamed: 5',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Unnamed: 9',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14']

# %%
change={'Back':"HDI_rank", 'Table 1. Human Development Index and its components ': 'Country', 'Unnamed: 2': "HDI", 'Unnamed: 4': "life_exp", 'Unnamed: 6': "school_exp",'Unnamed: 10': "GNI", 'Unnamed: 12': "GNI_min_HDI"}
gubo.rename(columns=change,inplace=True)
gubo
# Out:
#      HDI_rank                                            Country  \
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 4    HDI rank                                            Country
# ..        ...                                                ...
# 271       NaN                          Column 2: UNDESA (2022a).
# 272       NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 273       NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 274       NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 275       NaN  Column 6: Calculated based on data in columns ...
#
#                                 HDI  Unnamed: 3                  life_exp  \
# 0                               NaN         NaN                       NaN
# ...

# %%
keep=['HDI_rank', 'Country','HDI', 'life_exp', 'school_exp', 'GNI', 'GNI_min_HDI']
dontKeep = set(gubo.columns.to_list())-set(keep)
gubo = gubo.drop(columns=dontKeep)
gubo
# Out:
#      HDI_rank                                            Country  \
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 4    HDI rank                                            Country
# ..        ...                                                ...
# 271       NaN                          Column 2: UNDESA (2022a).
# 272       NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 273       NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 274       NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 275       NaN  Column 6: Calculated based on data in columns ...
#
#                                 HDI                  life_exp  \
# 0                               NaN                       NaN
# ...

# %%
#ELIMINAR LO QUE SOBRA EN LOS INICIOS Y CULMINACION

gubo = gubo.drop(range(0,7))
gubo
# Out:
#     HDI_rank                                            Country    HDI  \
# 7          1                                        Switzerland  0,962
# 8          2                                             Norway  0,961
# 9          3                                            Iceland  0,959
# 10         4                             Hong Kong, China (SAR)  0,952
# 11         5                                          Australia  0,951
# ..       ...                                                ...    ...
# 271      NaN                          Column 2: UNDESA (2022a).    NaN
# 272      NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...    NaN
# 273      NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...    NaN
# 274      NaN  Column 5: IMF (2022), UNDESA (2022b), United N...    NaN
# 275      NaN  Column 6: Calculated based on data in columns ...    NaN
#
#     life_exp school_exp     GNI GNI_min_HDI
# 7       84,0       16,5  66.933           5
# ...

# %%
#Eliminar textos que aparecen al final
gubo.tail(70)
# Out:
#     HDI_rank                                            Country    HDI  \
# 206      NaN                                                NaN    NaN
# 207      NaN                           Human development groups    NaN
# 208      NaN                        Very high human development  0,896
# 209      NaN                             High human development  0,754
# 210      NaN                           Medium human development  0,636
# ..       ...                                                ...    ...
# 271      NaN                          Column 2: UNDESA (2022a).    NaN
# 272      NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...    NaN
# 273      NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...    NaN
# 274      NaN  Column 5: IMF (2022), UNDESA (2022b), United N...    NaN
# 275      NaN  Column 6: Calculated based on data in columns ...    NaN
#
#     life_exp school_exp     GNI GNI_min_HDI
# 206      NaN        NaN     NaN         NaN
# ...

# %%
gubo = gubo.drop(range(206,276))
gubo
# Out:
#     HDI_rank                              Country    HDI life_exp school_exp  \
# 7          1                          Switzerland  0,962     84,0       16,5
# 8          2                               Norway  0,961     83,2       18,2
# 9          3                              Iceland  0,959     82,7       19,2
# 10         4               Hong Kong, China (SAR)  0,952     85,5       17,3
# 11         5                            Australia  0,951     84,5       21,1
# ..       ...                                  ...    ...      ...        ...
# 201      NaN       OTHER COUNTRIES OR TERRITORIES    NaN      NaN        NaN
# 202      NaN  Korea (Democratic People's Rep. of)     ..     73,3       10,8
# 203      NaN                               Monaco     ..     85,9         ..
# 204      NaN                                Nauru     ..     63,6       11,7
# 205      NaN                              Somalia     ..     55,3         ..
#
#         GNI GNI_min_HDI
# ...

# %%
#Eliminaremos las posiciones 201 al 206 de la data
gubo = gubo.drop(range(201,206))
gubo
# Out:
#     HDI_rank                   Country    HDI life_exp school_exp     GNI  \
# 7          1               Switzerland  0,962     84,0       16,5  66.933
# 8          2                    Norway  0,961     83,2       18,2  64.660
# 9          3                   Iceland  0,959     82,7       19,2  55.782
# 10         4    Hong Kong, China (SAR)  0,952     85,5       17,3  62.607
# 11         5                 Australia  0,951     84,5       21,1  49.238
# ..       ...                       ...    ...      ...        ...     ...
# 196      187                   Burundi  0,426     61,7       10,7     732
# 197      188  Central African Republic  0,404     53,9        8,0     966
# 198      189                     Niger  0,400     61,6        7,0   1.240
# 199      190                      Chad  0,394     52,5        8,0   1.364
# 200      191               South Sudan  0,385     55,0        5,5     768
#
#     GNI_min_HDI
# 7             5
# 8             6
# 9            11
# ...

# %%
gubo.shape
# Out:
# (194, 7)

# %%
valor = gubo.isnull().sum()
valor
# Out:
# HDI_rank       3
# Country        0
# HDI            3
# life_exp       3
# school_exp     3
# GNI            3
# GNI_min_HDI    3
# dtype: int64

# %%
gubo = gubo.dropna()

# %%
valor = gubo.isnull().sum()
valor
# Out:
# HDI_rank       0
# Country        0
# HDI            0
# life_exp       0
# school_exp     0
# GNI            0
# GNI_min_HDI    0
# dtype: int64

# %%
#Se eliminaron los subtitulos y ahora procedemos a limpiar
gubo
# Out:
#     HDI_rank                   Country    HDI life_exp school_exp     GNI  \
# 7          1               Switzerland  0,962     84,0       16,5  66.933
# 8          2                    Norway  0,961     83,2       18,2  64.660
# 9          3                   Iceland  0,959     82,7       19,2  55.782
# 10         4    Hong Kong, China (SAR)  0,952     85,5       17,3  62.607
# 11         5                 Australia  0,951     84,5       21,1  49.238
# ..       ...                       ...    ...      ...        ...     ...
# 196      187                   Burundi  0,426     61,7       10,7     732
# 197      188  Central African Republic  0,404     53,9        8,0     966
# 198      189                     Niger  0,400     61,6        7,0   1.240
# 199      190                      Chad  0,394     52,5        8,0   1.364
# 200      191               South Sudan  0,385     55,0        5,5     768
#
#     GNI_min_HDI
# 7             5
# 8             6
# 9            11
# ...

# %%
gubo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 191 entries, 7 to 200
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   HDI_rank     191 non-null    object
#  1   Country      191 non-null    object
#  2   HDI          191 non-null    object
#  3   life_exp     191 non-null    object
#  4   school_exp   191 non-null    object
#  5   GNI          191 non-null    object
#  6   GNI_min_HDI  191 non-null    object
# dtypes: object(7)
# memory usage: 16.0+ KB

# %%
set(gubo.GNI.str.extractall('(\W)').loc[:,0].to_list())-set('.')
# Out:
# set()

# %%
gubo['GNI']=gubo.GNI.str.replace(",",'.')
gubo['HDI']=gubo.HDI.str.replace(",",'.')
gubo['life_exp']=gubo.life_exp.str.replace(",",'.')
gubo['school_exp']=gubo.school_exp.str.replace(",",'.')
gubo
# Out:
#     HDI_rank                   Country    HDI life_exp school_exp     GNI  \
# 7          1               Switzerland  0.962     84.0       16.5  66.933
# 8          2                    Norway  0.961     83.2       18.2  64.660
# 9          3                   Iceland  0.959     82.7       19.2  55.782
# 10         4    Hong Kong, China (SAR)  0.952     85.5       17.3  62.607
# 11         5                 Australia  0.951     84.5       21.1  49.238
# ..       ...                       ...    ...      ...        ...     ...
# 196      187                   Burundi  0.426     61.7       10.7     732
# 197      188  Central African Republic  0.404     53.9        8.0     966
# 198      189                     Niger  0.400     61.6        7.0   1.240
# 199      190                      Chad  0.394     52.5        8.0   1.364
# 200      191               South Sudan  0.385     55.0        5.5     768
#
#     GNI_min_HDI
# 7             5
# 8             6
# 9            11
# ...

# %%
obj=gubo.select_dtypes(include=['object']).columns
obj
# Out:
# Index(['HDI_rank', 'Country', 'HDI', 'life_exp', 'school_exp', 'GNI',
#        'GNI_min_HDI'],
#       dtype='object')

# %%
gubo=gubo.loc[:,obj].apply(lambda col:col.str.strip())
gubo
# Out:
#     HDI_rank                   Country    HDI life_exp school_exp     GNI  \
# 7          1               Switzerland  0.962     84.0       16.5  66.933
# 8          2                    Norway  0.961     83.2       18.2  64.660
# 9          3                   Iceland  0.959     82.7       19.2  55.782
# 10         4    Hong Kong, China (SAR)  0.952     85.5       17.3  62.607
# 11         5                 Australia  0.951     84.5       21.1  49.238
# ..       ...                       ...    ...      ...        ...     ...
# 196      187                   Burundi  0.426     61.7       10.7     732
# 197      188  Central African Republic  0.404     53.9        8.0     966
# 198      189                     Niger  0.400     61.6        7.0   1.240
# 199      190                      Chad  0.394     52.5        8.0   1.364
# 200      191               South Sudan  0.385     55.0        5.5     768
#
#     GNI_min_HDI
# 7             5
# 8             6
# 9            11
# ...

# %%
obj1 = ['Country']
numCol = list(set(gubo.columns.to_list())- set(obj1))
numCol
# Out:
# ['GNI_min_HDI', 'HDI_rank', 'HDI', 'school_exp', 'GNI', 'life_exp']

# %%
def objToNum (xNum):
    import re
    xNum=pd.to_numeric(xNum)
    return xNum

# %%
gubo[numCol]= gubo.loc[:, numCol].applymap(objToNum)
gubo
# Out:
# <ipython-input-62-a99e9a313681>:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gubo[numCol]= gubo.loc[:, numCol].applymap(objToNum)
#      HDI_rank                   Country    HDI  life_exp  school_exp      GNI  \
# 7           1               Switzerland  0.962      84.0        16.5   66.933
# 8           2                    Norway  0.961      83.2        18.2   64.660
# 9           3                   Iceland  0.959      82.7        19.2   55.782
# 10          4    Hong Kong, China (SAR)  0.952      85.5        17.3   62.607
# 11          5                 Australia  0.951      84.5        21.1   49.238
# ..        ...                       ...    ...       ...         ...      ...
# 196       187                   Burundi  0.426      61.7        10.7  732.000
# 197       188  Central African Republic  0.404      53.9         8.0  966.000
# 198       189                     Niger  0.400      61.6         7.0    1.240
# ...

# %%
gubo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 191 entries, 7 to 200
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   HDI_rank     191 non-null    int64
#  1   Country      191 non-null    object
#  2   HDI          191 non-null    float64
#  3   life_exp     191 non-null    float64
#  4   school_exp   191 non-null    float64
#  5   GNI          191 non-null    float64
#  6   GNI_min_HDI  191 non-null    int64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 16.0+ KB

# %%
gubo[gubo.duplicated(subset='Country')]
# Out:
# Empty DataFrame
# Columns: [HDI_rank, Country, HDI, life_exp, school_exp, GNI, GNI_min_HDI]
# Index: []

# %%
gubo[gubo.Country.str.contains(r"[^\w\s]")]
# Out:
#      HDI_rank                             Country    HDI  life_exp  \
# 10          4              Hong Kong, China (SAR)  0.952      85.5
# 26         19                 Korea (Republic of)  0.925      83.7
# 83         76          Iran (Islamic Republic of)  0.774      73.9
# 88         80               Moldova (Republic of)  0.767      68.8
# 113       106                 Palestine, State of  0.715      73.5
# 126       118    Bolivia (Plurinational State of)  0.692      63.6
# 128       120  Venezuela (Bolivarian Republic of)  0.691      70.6
# 142       134    Micronesia (Federated States of)  0.628      70.7
# 148       140    Lao People's Democratic Republic  0.607      68.1
# 149       140                         Timor-Leste  0.607      67.7
# 152       144               Eswatini (Kingdom of)  0.597      57.1
# 167       159                       Côte d'Ivoire  0.550      58.6
# 169       160       Tanzania (United Republic of)  0.549      66.2
# ...

# %%
gubo[gubo.Country.str.contains(r"\w*[\u00C0-\u01DA']\w*")]
# Out:
#      HDI_rank                           Country    HDI  life_exp  school_exp  \
# 54         48                           Türkiye  0.838      76.0        18.3
# 148       140  Lao People's Democratic Republic  0.607      68.1        10.1
# 167       159                     Côte d'Ivoire  0.550      58.6        10.7
#
#         GNI  GNI_min_HDI
# 54   31.033           -3
# 148   7.700          -18
# 167   5.217          -22

# %%
pip install unidecode
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 4.8 MB/s eta 0:00:00
# ...

# %%
from unidecode import unidecode
gubo['Country']=gubo.Country.apply(unidecode)

# %%
#Colocamos los nombres de los países en mayuscula
gubo['Country']=gubo.Country.str.upper()
gubo
# Out:
#      HDI_rank                   Country    HDI  life_exp  school_exp      GNI  \
# 7           1               SWITZERLAND  0.962      84.0        16.5   66.933
# 8           2                    NORWAY  0.961      83.2        18.2   64.660
# 9           3                   ICELAND  0.959      82.7        19.2   55.782
# 10          4    HONG KONG, CHINA (SAR)  0.952      85.5        17.3   62.607
# 11          5                 AUSTRALIA  0.951      84.5        21.1   49.238
# ..        ...                       ...    ...       ...         ...      ...
# 196       187                   BURUNDI  0.426      61.7        10.7  732.000
# 197       188  CENTRAL AFRICAN REPUBLIC  0.404      53.9         8.0  966.000
# 198       189                     NIGER  0.400      61.6         7.0    1.240
# 199       190                      CHAD  0.394      52.5         8.0    1.364
# 200       191               SOUTH SUDAN  0.385      55.0         5.5  768.000
#
#      GNI_min_HDI
# ...

# %%
gubo[gubo.Country.str.contains(r"[(][^)]*[)]")]
# Out:
#      HDI_rank                             Country    HDI  life_exp  \
# 10          4              HONG KONG, CHINA (SAR)  0.952      85.5
# 26         19                 KOREA (REPUBLIC OF)  0.925      83.7
# 83         76          IRAN (ISLAMIC REPUBLIC OF)  0.774      73.9
# 88         80               MOLDOVA (REPUBLIC OF)  0.767      68.8
# 126       118    BOLIVIA (PLURINATIONAL STATE OF)  0.692      63.6
# 128       120  VENEZUELA (BOLIVARIAN REPUBLIC OF)  0.691      70.6
# 142       134    MICRONESIA (FEDERATED STATES OF)  0.628      70.7
# 152       144               ESWATINI (KINGDOM OF)  0.597      57.1
# 169       160       TANZANIA (UNITED REPUBLIC OF)  0.549      66.2
# 188       179  CONGO (DEMOCRATIC REPUBLIC OF THE)  0.479      59.2
#
#      school_exp     GNI  GNI_min_HDI
# 10         17.3  62.607            6
# 26         16.5  44.501            9
# 83         14.6  13.001           15
# 88         14.4  14.875           -1
# 126        14.9   8.111            0
# ...

# %%
gubo
# Out:
#      HDI_rank                   Country    HDI  life_exp  school_exp      GNI  \
# 7           1               SWITZERLAND  0.962      84.0        16.5   66.933
# 8           2                    NORWAY  0.961      83.2        18.2   64.660
# 9           3                   ICELAND  0.959      82.7        19.2   55.782
# 10          4    HONG KONG, CHINA (SAR)  0.952      85.5        17.3   62.607
# 11          5                 AUSTRALIA  0.951      84.5        21.1   49.238
# ..        ...                       ...    ...       ...         ...      ...
# 196       187                   BURUNDI  0.426      61.7        10.7  732.000
# 197       188  CENTRAL AFRICAN REPUBLIC  0.404      53.9         8.0  966.000
# 198       189                     NIGER  0.400      61.6         7.0    1.240
# 199       190                      CHAD  0.394      52.5         8.0    1.364
# 200       191               SOUTH SUDAN  0.385      55.0         5.5  768.000
#
#      GNI_min_HDI
# ...

# %%
gubo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 191 entries, 7 to 200
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   HDI_rank     191 non-null    int64
#  1   Country      191 non-null    object
#  2   HDI          191 non-null    float64
#  3   life_exp     191 non-null    float64
#  4   school_exp   191 non-null    float64
#  5   GNI          191 non-null    float64
#  6   GNI_min_HDI  191 non-null    int64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 16.0+ KB
